# %% [markdown]
# # FPL Machine Learning

# %%
import requests
import pandas as pd
import numpy as np
import glob


import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set_style("darkgrid")

# %% [markdown]
# ## Extracting data

# %%
#Vaastav data
path = '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws' # use your path
all_files = glob.glob(path + "/gw*.csv")

# %%
all_files
# Out:
# ['/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw16.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw17.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw15.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw14.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw10.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw11.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw13.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw12.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw8.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw9.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw4.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw5.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw7.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw6.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw2.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw3.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw1.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw19.csv',
#  '/Users/lukebetham/Documents/GitHub/Vaastav_FPL/data/2020-21/gws/gw18.csv']

# %%
df_all = pd.read_csv(all_files[0])
df_all["gw"] = all_files[0].split("/")[-1].split(".")[0].replace("gw","")
for filename in all_files[1:]:
    df_temp = pd.read_csv(filename)
    df_temp["gw"] = filename.split("/")[-1].split(".")[0].replace("gw","")
    df_all = pd.concat([df_all,df_temp])

# %%
df_all[df_all.name=='Juan Mata']
# Out:
#           name position     team   xP  assists  bonus  bps  clean_sheets  \
# 2    Juan Mata      MID  Man Utd  1.3        0      0    0             0
# 3    Juan Mata      MID  Man Utd  0.7        0      0    0             0
# 3    Juan Mata      MID  Man Utd  0.8        0      0    0             0
# 3    Juan Mata      MID  Man Utd  1.5        0      0    0             0
# 3    Juan Mata      MID  Man Utd  3.2        0      0    0             0
# 3    Juan Mata      MID  Man Utd  3.8        1      0   17             0
# 3    Juan Mata      MID  Man Utd  2.7        0      0    2             0
# 3    Juan Mata      MID  Man Utd  2.0        0      0    0             0
# 3    Juan Mata      MID  Man Utd  2.0        0      0    4             0
# 3    Juan Mata      MID  Man Utd  3.7        1      0   19             1
# 303  Juan Mata      MID  Man Utd  0.0        0      0    0             0
# 313  Juan Mata      MID  Man Utd  2.2        1      0   24             0
# 3    Juan Mata      MID  Man Utd  1.5        0      0    0             0
# 3    Juan Mata      MID  Man Utd  2.0        0      0   10             0
# 291  Juan Mata      MID  Man Utd  0.5        0      0    0             0
# 300  Juan Mata      MID  Man Utd  1.0        0      0    0             0
# 5    Juan Mata      MID  Man Utd  0.5        0      0    0             0
# 6    Juan Mata      MID  Man Utd  0.5        0      0    0             0
# 1    Juan Mata      MID  Man Utd  0.7        0      0    0             0
#
#      creativity  element  ...  team_h_score  threat  total_points  \
# 2           0.0      290  ...             1     0.0             0
# 3           0.0      290  ...             2     0.0             0
# 3           0.0      290  ...             2     0.0             0
# 3           0.0      290  ...             6     0.0             0
# 3           0.0      290  ...             2     0.0             0
# 3          15.2      290  ...             1     0.0             4
# 3           0.4      290  ...             2    19.0             1
# 3           0.0      290  ...             0     0.0             0
# 3           3.0      290  ...             1    12.0             2
# 3          17.9      290  ...             1     6.0             6
# 303         0.0      290  ...             1     0.0             0
# 313        46.5      290  ...             1    19.0             5
# 3           0.0      290  ...             0     0.0             0
# 3          38.9      290  ...             0    11.0             1
# 291         0.0      290  ...             1     0.0             0
# 300         0.0      290  ...             2     0.0             0
# 5           0.0      290  ...             0     0.0             0
# 6           0.0      290  ...             1     0.0             0
# 1           0.0      290  ...             0     0.0             0
#
#      transfers_balance  transfers_in transfers_out  value  was_home  \
# 2                 -254           104           358     59      True
# 3                 -241           137           378     58      True
# 3                 -621           249           870     59     False
# 3                 -287           252           539     59      True
# 3                  480          1149           669     59     False
# 3                 -760           490          1250     59     False
# 3                 -279           424           703     59     False
# 3                   84           745           661     59      True
# 3                 -696           433          1129     59     False
# 3                  321          1265           944     59      True
# 303               -649           611          1260     59      True
# 313               -680           529          1209     59     False
# 3                   91          1069           978     59      True
# 3                  937          1741           804     59      True
# 291               -391           641          1032     60      True
# 300              -1553           361          1914     60     False
# 5                 -111           100           211     58     False
# 6                 -111           100           211     58     False
# 1                 -259           253           512     58     False
#
#      yellow_cards  gw
# 2               0  16
# 3               0  17
# 3               0  15
# 3               0  14
# 3               0  10
# 3               0  11
# 3               0  13
# 3               0  12
# 3               0   8
# 3               0   9
# 303             0   4
# 313             0   5
# 3               0   7
# 3               0   6
# 291             0   2
# 300             0   3
# 5               0  19
# 6               0  19
# 1               0  18
#
# [19 rows x 36 columns]

# %% [markdown]
# ### Extracting all Players and Teams data

# %%
#game data
url = 'https://fantasy.premierleague.com/api/bootstrap-static/'

r = requests.get(url)

json_data = r.json()

player_df = pd.DataFrame(json_data['elements'])
player_types_df = pd.DataFrame(json_data['element_types'])
teams_df = pd.DataFrame(json_data['teams'])

json_data.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types'])

# %%
json_data['element_stats']
# Out:
# [{'label': 'Minutes played', 'name': 'minutes'},
#  {'label': 'Goals scored', 'name': 'goals_scored'},
#  {'label': 'Assists', 'name': 'assists'},
#  {'label': 'Clean sheets', 'name': 'clean_sheets'},
#  {'label': 'Goals conceded', 'name': 'goals_conceded'},
#  {'label': 'Own goals', 'name': 'own_goals'},
#  {'label': 'Penalties saved', 'name': 'penalties_saved'},
#  {'label': 'Penalties missed', 'name': 'penalties_missed'},
#  {'label': 'Yellow cards', 'name': 'yellow_cards'},
#  {'label': 'Red cards', 'name': 'red_cards'},
#  {'label': 'Saves', 'name': 'saves'},
#  {'label': 'Bonus', 'name': 'bonus'},
#  {'label': 'Bonus Points System', 'name': 'bps'},
#  {'label': 'Influence', 'name': 'influence'},
#  {'label': 'Creativity', 'name': 'creativity'},
#  {'label': 'Threat', 'name': 'threat'},
#  {'label': 'ICT Index', 'name': 'ict_index'}]

# %% [markdown]
# events = summary stats for each gameweek
# game_settings = overall settings for the game
# phases = start and stop gameweeks for months
# teams = summary data about the teams - seemingly no points/league table filled in though
# total_players = number of total players globally
# elements = all players and some summary stats
# element_stats = mapping for player stats labels eg. {'label': 'Goals scored', 'name': 'goals_scored'}
# element_types = positions and the rules per position

# %% [markdown]
# ### Extracting Fixtures

# %%
#game data
url = 'https://fantasy.premierleague.com/api/fixtures/'

r = requests.get(url)

json_data = r.json()

fixtures_df = pd.DataFrame(json_data)

# %% [markdown]
# ## Getting all events for all players

# %%
player_df
# Out:
#      chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 0                             0.0                           0.0   37605
# 1                             0.0                           0.0   39476
# 2                           100.0                         100.0   41270
# 3                             0.0                           0.0   54694
# 4                           100.0                         100.0   58822
# ..                            ...                           ...     ...
# 638                           NaN                           NaN  481626
# 639                           NaN                           NaN  448487
# 640                           NaN                           NaN  209353
# 641                           NaN                           NaN  465551
# 642                           0.0                           0.0   73314
#
#      cost_change_event  cost_change_event_fall  cost_change_start  \
# 0                    0                       0                 -3
# 1                    0                       0                 -2
# 2                    0                       0                 -1
# 3                    0                       0                 -7
# 4                    0                       0                 -4
# ..                 ...                     ...                ...
# 638                  0                       0                  0
# 639                  0                       0                  0
# 640                 -1                       1                 -1
# 641                  0                       0                  0
# 642                  0                       0                  0
#
#      cost_change_start_fall  dreamteam_count  element_type ep_next  ...  \
# 0                         3                0             3     0.0  ...
# 1                         2                0             2     0.0  ...
# 2                         1                0             2     2.6  ...
# 3                         7                1             3     0.0  ...
# 4                         4                0             2     2.8  ...
# ..                      ...              ...           ...     ...  ...
# 638                       0                0             2     0.0  ...
# 639                       0                0             1     0.0  ...
# 640                       1                0             4     0.7  ...
# 641                       0                0             2     0.0  ...
# 642                       0                0             4     0.0  ...
#
#     threat_rank  threat_rank_type ict_index_rank ict_index_rank_type  \
# 0           642               258            642                 258
# 1           583               215            603                 219
# 2           253                77            300                  99
# 3            22                13             34                  22
# 4           372               139            356                 130
# ..          ...               ...            ...                 ...
# 638         460               180            510                 196
# 639         456                23            506                  53
# 640         396                60            466                  61
# 641         459               179            509                 195
# 642         643                84            643                  84
#
#      corners_and_indirect_freekicks_order  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 638                                   NaN
# 639                                   NaN
# 640                                   NaN
# 641                                   NaN
# 642                                   NaN
#
#      corners_and_indirect_freekicks_text direct_freekicks_order  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           4.0
# 3                                                           NaN
# 4                                                           NaN
# ..                                   ...                    ...
# 638                                                         NaN
# 639                                                         NaN
# 640                                                         NaN
# 641                                                         NaN
# 642                                                         NaN
#
#     direct_freekicks_text  penalties_order penalties_text
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      1.0
# 4                                      NaN
# ..                    ...              ...            ...
# 638                                    NaN
# 639                                    NaN
# 640                                    NaN
# 641                                    NaN
# 642                                    NaN
#
# [643 rows x 67 columns]

# %% [markdown]
# ### Extracting My Team

# %%
team_id = '1409005'
url2 = 'https://fantasy.premierleague.com/api/my-team/{}'.format(team_id)

# %%
password = input('Password=')
session = requests.session()

url = 'https://users.premierleague.com/accounts/login/'
payload = {
 'password': password,
 'login': 'lukebetham@hotmail.com',
 'redirect_uri': 'https://fantasy.premierleague.com/a/login',
 'app': 'plfpl-web'
}

session.post(url, data=payload)

response = session.get(url2)

json = response.json()
clear_output()
del password

myteam_df = pd.DataFrame(json['picks'])

# %%
myteam_df
# Out:
#     element  position  selling_price  multiplier  purchase_price  is_captain  \
# 0       363         1             46           1              45       False
# 1       232         2             60           1              59       False
# 2       239         3             47           1              45       False
# 3       558         4             47           1              47       False
# 4       254         5            124           1             123       False
# 5       302         6            110           2             106        True
# 6       390         7             93           1              90       False
# 7        37         8             75           1              74       False
# 8       449         9             51           1              50       False
# 9       506        10             66           1              66       False
# 10      202        11             64           1              61       False
# 11      417        12             45           0              45       False
# 12      514        13             60           0              59       False
# 13      459        14             48           0              50       False
# 14      376        15             48           0              48       False
#
#     is_vice_captain
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# 5             False
# 6             False
# 7              True
# 8             False
# 9             False
# 10            False
# 11            False
# 12            False
# 13            False
# 14            False

# %% [markdown]
# ## Joining and cleaning

# %% [markdown]
# ### Player dataframe

# %%
player_df['value']=player_df['total_points']/player_df['now_cost']
player_df.element_type = player_df.element_type.map(pd.Series(player_types_df.plural_name.values,index=player_types_df.id).to_dict())
player_df.team = player_df.team.map(pd.Series(teams_df.name.values,teams_df.id).to_dict())
player_clean_df = player_df[['id','web_name','code','element_type','team',
           'total_points','value','now_cost','points_per_game','form','selected_by_percent','minutes',
           'transfers_in_event', 'transfers_out_event',
           'chance_of_playing_next_round','news','status',
           'bps','goals_scored','assists', 'clean_sheets', 'goals_conceded', 'own_goals',
           'penalties_saved', 'penalties_missed', 'yellow_cards', 'red_cards','saves']]

# %%
player_clean_df.team.value_counts()
# Out:
# Wolves            39
# Man Utd           37
# Brighton          37
# Arsenal           34
# Southampton       34
# Fulham            34
# Man City          33
# Newcastle         33
# Crystal Palace    32
# Leeds             32
# West Brom         32
# Liverpool         31
# Burnley           31
# Spurs             31
# Aston Villa       31
# Leicester         29
# West Ham          29
# Everton           29
# Sheffield Utd     28
# Chelsea           27
# Name: team, dtype: int64

# %% [markdown]
# ### Current Player performance

# %%
include_teams = ['Man Utd','Spurs','Everton','Aston Villa','Man City','Burnley',
                 'Wolves','Arsenal','Crystal Palace','Brighton','Sheffield Utd',
                'Newcastle']
player_clean_df = player_clean_df[player_clean_df.team.isin(include_teams)]

# %%
for pos in player_clean_df.element_type.unique():
    df_temp = player_clean_df[player_clean_df.element_type==pos]
    for column in ['total_points','value']:
        plt.figure(figsize=(12,8))
        chart=sns.barplot(x='web_name',y=column,data=df_temp.sort_values(column,ascending=False).iloc[:15],hue='team',dodge=False)
        plt.title(pos+" by "+column.replace('_',' '))
        plt.xticks(rotation=30,ha="right")
        for p in chart.patches:
            chart.annotate(round(p.get_height(),2), (p.get_x() + p.get_width() / 2., p.get_height()),
             ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
             textcoords='offset points')
        plt.show()

# %% [markdown]
# ### Team Current Rankings

# %%
fixtures_df["home_win"]=(fixtures_df.team_a_score-fixtures_df.team_h_score).apply(lambda x: 1 if x < 0 else 0)
fixtures_df["draw"]=(fixtures_df.team_a_score-fixtures_df.team_h_score).apply(lambda x: 1 if x == 0 else 0)
fixtures_df["away_win"]=(fixtures_df.team_a_score-fixtures_df.team_h_score).apply(lambda x: 1 if x > 0 else 0)
fixtures_df["home_cleansheet"] = fixtures_df.team_a_score.apply(lambda x: 1 if x == 0 else 0)
fixtures_df["home_scored"] = fixtures_df.team_h_score.apply(lambda x: 1 if x != 0 else 0)
fixtures_df["away_cleansheet"] = fixtures_df.team_h_score.apply(lambda x: 1 if x == 0 else 0)
fixtures_df["away_scored"] = fixtures_df.team_a_score.apply(lambda x: 1 if x != 0 else 0)

# %%
away_df = fixtures_df[fixtures_df['finished']==True].groupby('team_a').agg({'finished':'count',
                                                                            'away_win':'sum',
                                                                            "team_a_score":'sum',
                                                                            "team_h_score":'sum',
                                                                            "away_cleansheet":'sum',
                                                                            "away_scored":'sum'})
home_df = fixtures_df[fixtures_df['finished']==True].groupby('team_h').agg({'finished':'count',
                                                                            'home_win':'sum',
                                                                            "team_h_score":'sum',
                                                                            "team_a_score":'sum',
                                                                            "home_cleansheet":'sum',
                                                                            "away_scored":'sum'})
away_df.columns = ["played_away","won_away",'score_away','conceded_away','cleansheet_away','scored_away']
home_df.columns = ["played_home","won_home",'score_home','conceded_home','cleansheet_home','scored_home']
results_df = pd.merge(home_df,away_df,left_index=True,right_index=True)

# %%
results_df['win_ratio'] = (results_df['won_home']+results_df['won_away'])/ \
                            (results_df['played_home']+results_df['played_away'])
results_df['scored_ratio'] = (results_df['scored_away']+results_df['scored_home'])/ \
                            (results_df['played_home']+results_df['played_away'])
results_df['cleansheet_ratio'] = (results_df['cleansheet_away']+results_df['cleansheet_home'])/ \
                            (results_df['played_home']+results_df['played_away'])
results_df['goals_per_match'] = (results_df['score_home']+results_df['score_away'])/ \
                            (results_df['played_home']+results_df['played_away'])
results_df['home_away_bias'] = (results_df['won_home']/results_df['played_home'])- \
                                (results_df['won_away']/results_df['played_away'])
results_df = pd.merge(teams_df[['id','name']],results_df.reset_index(),left_on='id',right_on='team_h')

# %% [markdown]
# ### Current Team performance

# %%
for column in results_df.columns[-5:]:
    plt.figure(figsize=(12,6))
    chart=sns.barplot(x='name',y=column,data=results_df.sort_values(column,ascending=False))
    plt.title("Team by "+column.replace('_',' '))
    plt.xticks(rotation=30,ha="right")
    for p in chart.patches:
        chart.annotate(round(p.get_height(),2), (p.get_x() + p.get_width() / 2., p.get_height()),
         ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
         textcoords='offset points')
    if column == 'home_away_bias':
        plt.xlabel("<---Better at home -------------- Better Away--->")
    plt.show()

# %% [markdown]
# ### FPL Team ranking

# %%
results_df.iloc[:,-5:]
# Out:
#     win_ratio  scored_ratio  cleansheet_ratio  goals_per_match  home_away_bias
# 0    0.375000      0.812500          0.250000         1.000000        0.000000
# 1    0.571429      0.785714          0.571429         2.000000       -0.285714
# 2    0.125000      0.812500          0.187500         1.125000       -0.250000
# 3    0.266667      0.533333          0.400000         0.600000        0.303571
# 4    0.437500      0.687500          0.375000         1.937500        0.125000
# 5    0.312500      0.687500          0.062500         1.250000       -0.125000
# 6    0.600000      0.866667          0.266667         1.733333       -0.053571
# 7    0.133333      0.600000          0.200000         0.866667       -0.017857
# 8    0.562500      0.812500          0.312500         1.812500       -0.375000
# 9    0.437500      0.875000          0.375000         1.875000       -0.125000
# 10   0.562500      0.812500          0.312500         2.312500        0.625000
# 11   0.500000      0.571429          0.500000         1.500000        0.142857
# 12   0.600000      0.733333          0.266667         2.066667       -0.482143
# 13   0.333333      0.800000          0.200000         1.133333        0.089286
# 14   0.000000      0.750000          0.000000         0.500000        0.000000
# 15   0.437500      0.562500          0.437500         1.562500        0.125000
# 16   0.466667      0.800000          0.333333         1.733333       -0.071429
# 17   0.062500      0.687500          0.125000         0.687500        0.125000
# 18   0.375000      0.750000          0.312500         1.437500        0.000000
# 19   0.375000      0.625000          0.250000         0.937500        0.000000

# %% [markdown]
# ### Fixture rating
