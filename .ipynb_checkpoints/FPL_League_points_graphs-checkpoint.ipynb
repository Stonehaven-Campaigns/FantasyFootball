# %%
import requests
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set_style("darkgrid")

# %%
import datapane as dp

# %%
#game data
url = 'https://fantasy.premierleague.com/api/bootstrap-static/'

r = requests.get(url)

json_data = r.json()

elements_df = pd.DataFrame(json_data['elements'])
elements_types_df = pd.DataFrame(json_data['element_types'])
teams_df = pd.DataFrame(json_data['teams'])

# %%
json_data.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types'])

# %%
json_data['total_players']
# Out:
# 8074520

# %%
url = 'https://fantasy.premierleague.com/api/leagues-classic/617009/standings/'

r = requests.get(url)

league = r.json()

df_league = pd.DataFrame(league['standings']['results'])

df_league
# Out:
#           id  event_total         player_name  rank  last_rank  rank_sort  \
# 0   20241183           76      Henry Turnbull     1          1          1
# 1   16819673           73          Ted Rosner     2          2          2
# 2   25158712           71  George Baker Baker     3          4          3
# 3   22488436           72       Pete Stebbing     4          6          4
# 4   21699595           74          Henry Elks     5          7          5
# 5   20076908           59           Sam Guest     6          3          6
# 6   16523966           61        James Rivers     7          5          7
# 7   23673927           60       Nick Sissling     8          9          8
# 8   23446904           58         Luke Betham     9         10          9
# 9   33365266           57         Leo Anthias    10         11         10
# 10  43941031           47   James Fazackerley    11          8         11
# 11  29875475           71                 A A    12         12         12
# 12  48853375           74         Toby Powell    13         13         13
#
#     total    entry           entry_name
# 0     333  1364762      Expected Ghouls
# 1     327   107878      Blaise Maweedie
# 2     310  1796385           Borocelona
# 3     308  1861744     Diego Marastebbo
# 4     306  2631883   Debbie Does Gallas
# 5     300   776505         Tossed Salah
# 6     294  2805214       Cry me a River
# 7     288  3651523      Sissling Select
# 8     285  1583735          Nanas Squad
# 9     279  4910848          Football FC
# 10    276  1447926     Mike Dean's Bean
# 11    269  1390493                Nanas
# 12    259  6229066  Tubbalubba Kings XI

# %%
url = 'https://fantasy.premierleague.com/api/entry/4914782/history/'
r = requests.get(url)
json = r.json()
json.keys()
# Out:
# dict_keys(['current', 'past', 'chips'])

# %%
pd.DataFrame(json['past'])
# Out:
#   season_name  total_points     rank
# 0     2018/19          1579  5230067
# 1     2019/20          1883  3291247
# 2     2020/21          2045  2191579

# %%
df_all = pd.DataFrame(columns=['event', 'points', 'total_points', 'rank', 'rank_sort', 'overall_rank',
       'bank', 'value', 'event_transfers', 'event_transfers_cost',
       'points_on_bench', 'player','team_name'])
# get all players data from a league
for i, val in enumerate(df_league.entry):
    url = 'https://fantasy.premierleague.com/api/entry/{}/history/'.format(val)

    r = requests.get(url)

    json = r.json()

    df_temp=pd.DataFrame(json['current'])
    print(val,df_league.iloc[i,2],df_league.iloc[i,8])
    df_temp['player'] = df_league.iloc[i,2]
    df_temp['team_name'] = df_league.iloc[i,8]
    df_all= pd.concat([df_all,df_temp])
# Out:
# 1364762 Henry Turnbull Expected Ghouls
# 107878 Ted Rosner Blaise Maweedie
# 1796385 George Baker Baker Borocelona
# 1861744 Pete Stebbing Diego Marastebbo
# 2631883 Henry Elks Debbie Does Gallas
# 776505 Sam Guest Tossed Salah
# 2805214 James Rivers Cry me a River
# 3651523 Nick Sissling Sissling Select
# 1583735 Luke Betham Nanas Squad
# 4910848 Leo Anthias Football FC
# 1447926 James Fazackerley Mike Dean's Bean
# 1390493 A A Nanas
# 6229066 Toby Powell Tubbalubba Kings XI

# %%
# cleaning
for col in df_all:
    try:
        df_all[col]=df_all[col].astype(float)
    except:
        pass
    
df_all['player'] = df_all['player'].apply(lambda x: "Alex Andreou" if x == "A A" else x)
df_all['player'] = df_all['player'].apply(lambda x: "Turnbull" if x == "Henry Turnbull" else x)
df_all['player'] = df_all['player'].apply(lambda x: "Faz" if x == "James Fazackerley" else x)
df_all['player'] = df_all['player'].apply(lambda x: "Elks" if x == "Henry Elks" else x)
df_all['player'] = df_all['player'].apply(lambda x: x.split()[0])

# %%
# Total points on Bench
df_temp = df_all.groupby('player').sum()[['points_on_bench']].sort_values('points_on_bench')
plt.figure(figsize=(12,8))
bench_chart=sns.barplot(y=df_temp.points_on_bench,x=df_temp.index)
plt.title("Total Points on Bench")
plt.xticks(rotation=30,ha="right")
for p in bench_chart.patches:
    bench_chart.annotate(round(p.get_height(),2), (p.get_x() + p.get_width() / 2., p.get_height()),
     ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
     textcoords='offset points')
plt.show()

# %%
# Extra Transfers cost
df_temp = df_all.groupby('player').sum()[['event_transfers_cost']].sort_values('event_transfers_cost')
plt.figure(figsize=(12,8))
x_transfers = sns.barplot(y=df_temp.event_transfers_cost,x=df_temp.index,palette='Reds')
plt.title("Total Points spent on Extra Transfers")
plt.xticks(rotation=30,ha="right")
for p in x_transfers.patches:
    x_transfers.annotate(round(p.get_height(),2), (p.get_x() + p.get_width() / 2., p.get_height()),
     ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
     textcoords='offset points')
plt.show()

# %%
# Max points in a week
df_temp = df_all.groupby('player').max()[['points']].sort_values('points')
plt.figure(figsize=(12,8))
max_week = sns.barplot(y=df_temp.points,x=df_temp.index,palette='Blues_d')
plt.title("Max points in a Week")
plt.xticks(rotation=30,ha="right")
for p in max_week.patches:
    max_week.annotate(round(p.get_height(),2), (p.get_x() + p.get_width() / 2., p.get_height()),
     ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
     textcoords='offset points')
plt.ylim(65,160)
plt.show()

# %%
# Std dev points 
df_temp = df_all.groupby('player').std()[['points']].sort_values('points')
plt.figure(figsize=(12,8))
consistency=sns.barplot(y=df_temp.points,x=df_temp.index,palette="GnBu_d")
plt.title("Consistency - Standard Deviation of points")
plt.xticks(rotation=30,ha="right")
for p in consistency.patches:
    consistency.annotate(round(p.get_height(),2), (p.get_x() + p.get_width() / 2., p.get_height()),
     ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
     textcoords='offset points')
plt.show()

# %%
# Best UK Rank Percentile in a gameweek
df_temp = df_all.groupby('player').min()[['rank']].sort_values('rank')/int(json_data['total_players'])*100
plt.figure(figsize=(12,8))
chart=sns.barplot(y=df_temp['rank'],x=df_temp.index)
plt.title("Best All Players Rank Percentile - in a gameweek")
plt.xticks(rotation=30,ha="right")
for p in chart.patches:
    chart.annotate(round(p.get_height(),2), (p.get_x() + p.get_width() / 2., p.get_height()),
     ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
     textcoords='offset points')
plt.show()

# %%
# Worst UK Rank Percentile in a gameweek
df_temp = df_all.groupby('player').max()[['rank']].sort_values('rank')/int(json_data['total_players'])*100
plt.figure(figsize=(12,8))
chart = sns.barplot(y=df_temp['rank'],x=df_temp.index)
plt.title("Worst All Players Rank Percentile - in a gameweek")
plt.xticks(rotation=30,ha="right")
for p in chart.patches:
    chart.annotate(round(p.get_height(),2), (p.get_x() + p.get_width() / 2., p.get_height()),
     ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
     textcoords='offset points')
plt.show()

# %%
# Current all players rank
df_temp = df_all[df_all['event']==df_all['event'].max()][['overall_rank','player']].sort_values('overall_rank')
df_temp['overall_rank']=df_temp['overall_rank']/int(json_data['total_players'])*100
plt.figure(figsize=(12,8))
current_percentile = sns.barplot(y=df_temp['overall_rank'],x=df_temp.player, palette = "RdBu_r")
plt.title("Current All Players Rank Percentile - overall")
plt.xticks(rotation=30,ha="right")
for p in current_percentile.patches:
    current_percentile.annotate(round(p.get_height(),2), (p.get_x() + p.get_width() / 2., p.get_height()),
     ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
     textcoords='offset points')
plt.show()

# %%
# Best UK Rank Percentile in a gameweek
df_temp = df_all.groupby('player').min()[['overall_rank']].sort_values('overall_rank')/int(json_data['total_players'])*100
plt.figure(figsize=(12,8))
chart = sns.barplot(y=df_temp['overall_rank'],x=df_temp.index)
plt.title("Best All Players Rank Percentile - overall")
plt.xticks(rotation=30,ha="right")
for p in chart.patches:
    chart.annotate(round(p.get_height(),2), (p.get_x() + p.get_width() / 2., p.get_height()),
     ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
     textcoords='offset points')
plt.show()

# %%
# Best UK Rank Percentile in a gameweek
df_temp = df_all.groupby('player').max()[['overall_rank']].sort_values('overall_rank')/int(json_data['total_players'])*100
plt.figure(figsize=(12,8))
chart = sns.barplot(y=df_temp['overall_rank'],x=df_temp.index)
plt.title("Worst All Players Rank Percentile - overall")
plt.xticks(rotation=30,ha="right")
for p in chart.patches:
    chart.annotate(round(p.get_height(),2), (p.get_x() + p.get_width() / 2., p.get_height()),
     ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
     textcoords='offset points')
plt.show()

# %%
df_all = df_all.sort_values(by='event')
rank_list = []
for e in df_all.event.unique():
    df_temp = df_all[df_all.event==e]
    rank_list+=df_temp.total_points.rank(method='min',ascending=False).tolist()

# %%
df_all['rankpw']=rank_list

# %%
df_all
# Out:
#    event  points  total_points       rank  rank_sort  overall_rank  bank  \
# 0    1.0   112.0         112.0    31939.0    36188.0       31939.0   0.0
# 0    1.0    94.0          94.0   817703.0   866188.0      817700.0   0.0
# 0    1.0    94.0          94.0   817703.0   863722.0      817700.0   0.0
# 0    1.0   106.0         106.0   122432.0   142017.0      122431.0   0.0
# 0    1.0    97.0          97.0   567570.0   589393.0      567567.0   0.0
# 0    1.0   101.0         101.0   316057.0   342750.0      316055.0   0.0
# 0    1.0    90.0          90.0  1176051.0  1259450.0     1176048.0   0.0
# 0    1.0    93.0          93.0   911355.0   942618.0      911352.0   0.0
# 0    1.0    96.0          96.0   633476.0   650790.0      633473.0   0.0
# 0    1.0    89.0          89.0  1281019.0  1308171.0     1281016.0   0.0
# 0    1.0   106.0         106.0   122432.0   124495.0      122431.0   5.0
# 0    1.0    85.0          85.0  1676991.0  1776464.0     1676988.0   5.0
# 0    1.0    85.0          85.0  1676991.0  1702477.0     1676988.0   0.0
# 1    2.0    76.0         172.0   639116.0   646858.0      359456.0   0.0
# 1    2.0    73.0         158.0   989758.0   998802.0      905892.0   5.0
# 1    2.0    59.0         156.0  2989925.0  3006366.0      973395.0   0.0
# 1    2.0    59.0         165.0  3086955.0  3120427.0      622171.0  20.0
# 1    2.0    54.0         143.0  4061611.0  4073943.0     1709129.0   0.0
# 1    2.0    53.0         138.0  4157158.0  4230337.0     2019692.0   5.0
# 1    2.0    69.0         159.0  1394131.0  1434721.0      841081.0   0.0
# 1    2.0    81.0         175.0   308476.0   320849.0      281909.0   0.0
# 1    2.0    84.0         196.0   180128.0   186184.0       22065.0   0.0
# 1    2.0    77.0         171.0   565755.0   580155.0      387441.0   0.0
# 1    2.0    81.0         187.0   308476.0   309898.0       69795.0   5.0
# 1    2.0    81.0         174.0   308476.0   317707.0      304407.0   0.0
# 1    2.0    74.0         175.0   823932.0   842416.0      281909.0   0.0
# 2    3.0    65.0         236.0  1608569.0  1632247.0      358601.0  13.0
# 2    3.0    69.0         265.0   905720.0   915975.0       16366.0   0.0
# 2    3.0    59.0         198.0  2944148.0  2956238.0     1900657.0   4.0
# 2    3.0    71.0         229.0   616314.0   626193.0      556051.0   1.0
# 2    3.0    71.0         258.0   652242.0   653225.0       38760.0   3.0
# 2    3.0    63.0         222.0  2029829.0  2070750.0      794432.0  11.0
# 2    3.0    71.0         227.0   652242.0   661543.0      620209.0   4.0
# 2    3.0    65.0         239.0  1550352.0  1568805.0      281624.0   4.0
# 2    3.0    69.0         241.0   905720.0   912269.0      247654.0   2.0
# 2    3.0    63.0         228.0  1966629.0  2003176.0      587740.0   9.0
# 2    3.0    61.0         236.0  2415508.0  2437086.0      351378.0   5.0
# 2    3.0    51.0         189.0  4807450.0  4843199.0     2425110.0   0.0
# 2    3.0    62.0         237.0  2253573.0  2279326.0      334038.0   9.0
# 3    4.0    60.0         288.0  3380799.0  3408086.0      635515.0   9.0
# 3    4.0    59.0         300.0  3622244.0  3628352.0      352336.0   2.0
# 3    4.0    71.0         269.0  1103054.0  1118774.0     1283644.0   3.0
# 3    4.0    76.0         333.0   568276.0   570601.0       21143.0   4.0
# 3    4.0    61.0         294.0  3187879.0  3205482.0      488576.0   6.0
# 3    4.0    71.0         310.0  1193031.0  1202393.0      188182.0   8.0
# 3    4.0    72.0         308.0  1044739.0  1053557.0      216372.0   0.0
# 3    4.0    73.0         327.0   906088.0   907178.0       39564.0   7.0
# 3    4.0    57.0         279.0  4104967.0  4143637.0      911026.0   9.0
# 3    4.0    74.0         306.0   775603.0   787391.0      251484.0  12.0
# 3    4.0    58.0         285.0  3864028.0  3876330.0      721597.0   3.0
# 3    4.0    47.0         276.0  6288344.0  6296432.0     1015027.0   6.0
# 3    4.0    74.0         259.0   775603.0   799094.0     1750575.0   9.0
#
#     value  event_transfers  event_transfers_cost  points_on_bench    player  \
# 0  1000.0              0.0                   0.0              2.0  Turnbull
# 0  1000.0              0.0                   0.0              1.0     James
# 0  1000.0              0.0                   0.0              3.0      Elks
# 0  1000.0              0.0                   0.0              5.0      Nick
# 0  1000.0              0.0                   0.0              2.0      Luke
# 0  1000.0              0.0                   0.0             12.0      Pete
# 0  1000.0              0.0                   0.0              6.0       Leo
# 0  1000.0              0.0                   0.0              4.0    George
# 0  1000.0              0.0                   0.0             14.0       Sam
# 0  1000.0              0.0                   0.0              8.0      Alex
# 0  1000.0              0.0                   0.0              9.0       Ted
# 0  1000.0              0.0                   0.0              8.0      Toby
# 0  1000.0              0.0                   0.0              4.0       Faz
# 1  1004.0              0.0                   0.0              8.0       Sam
# 1  1001.0              1.0                   0.0              4.0       Faz
# 1  1003.0              0.0                   0.0              0.0      Luke
# 1  1005.0              1.0                   0.0             11.0      Nick
# 1  1004.0              1.0                   0.0              3.0      Alex
# 1  1003.0              0.0                   0.0              2.0      Toby
# 1  1003.0              0.0                   0.0              1.0       Leo
# 1  1004.0              0.0                   0.0              0.0     James
# 1  1005.0              0.0                   0.0              2.0  Turnbull
# 1  1004.0              0.0                   0.0              8.0      Elks
# 1  1005.0              0.0                   0.0              4.0       Ted
# 1  1004.0              0.0                   0.0              4.0    George
# 1  1004.0              0.0                   0.0              0.0      Pete
# 2  1007.0              2.0                   0.0              1.0      Elks
# 2  1011.0              2.0                   0.0              1.0  Turnbull
# 2  1006.0              2.0                   4.0              6.0      Alex
# 2  1003.0              1.0                   0.0              3.0       Faz
# 2  1014.0              2.0                   0.0              4.0       Ted
# 2  1005.0              2.0                   0.0              1.0       Leo
# 2  1004.0              2.0                   0.0              2.0      Luke
# 2  1006.0              1.0                   0.0              2.0    George
# 2  1012.0              2.0                   0.0              4.0       Sam
# 2  1008.0              1.0                   0.0              4.0      Nick
# 2  1010.0              1.0                   0.0              3.0      Pete
# 2  1003.0              2.0                   0.0             12.0      Toby
# 2  1010.0              2.0                   0.0              1.0     James
# 3  1006.0              1.0                   0.0              3.0      Nick
# 3  1010.0              1.0                   0.0              0.0       Sam
# 3  1004.0              0.0                   0.0              5.0      Alex
# 3  1011.0              3.0                   8.0              7.0  Turnbull
# 3  1008.0              2.0                   4.0              8.0     James
# 3  1005.0              2.0                   0.0              6.0    George
# 3  1010.0              2.0                   0.0              1.0      Pete
# 3  1014.0              2.0                   4.0              0.0       Ted
# 3  1003.0              1.0                   0.0              0.0       Leo
# 3  1006.0              2.0                   4.0              8.0      Elks
# 3  1002.0              1.0                   0.0              9.0      Luke
# 3  1002.0              1.0                   0.0              7.0       Faz
# 3  1001.0              2.0                   4.0             10.0      Toby
#
#              team_name  rankpw
# 0      Expected Ghouls     1.0
# 0       Cry me a River     7.0
# 0   Debbie Does Gallas     7.0
# 0      Sissling Select     2.0
# 0          Nanas Squad     5.0
# 0     Diego Marastebbo     4.0
# 0          Football FC    10.0
# 0           Borocelona     9.0
# 0         Tossed Salah     6.0
# 0                Nanas    11.0
# 0      Blaise Maweedie     2.0
# 0  Tubbalubba Kings XI    12.0
# 0     Mike Dean's Bean    12.0
# 1         Tossed Salah     6.0
# 1     Mike Dean's Bean    10.0
# 1          Nanas Squad    11.0
# 1      Sissling Select     8.0
# 1                Nanas    12.0
# 1  Tubbalubba Kings XI    13.0
# 1          Football FC     9.0
# 1       Cry me a River     3.0
# 1      Expected Ghouls     1.0
# 1   Debbie Does Gallas     7.0
# 1      Blaise Maweedie     2.0
# 1           Borocelona     5.0
# 1     Diego Marastebbo     3.0
# 2   Debbie Does Gallas     6.0
# 2      Expected Ghouls     1.0
# 2                Nanas    12.0
# 2     Mike Dean's Bean     8.0
# 2      Blaise Maweedie     2.0
# 2          Football FC    11.0
# 2          Nanas Squad    10.0
# 2           Borocelona     4.0
# 2         Tossed Salah     3.0
# 2      Sissling Select     9.0
# 2     Diego Marastebbo     6.0
# 2  Tubbalubba Kings XI    13.0
# 2       Cry me a River     5.0
# 3      Sissling Select     8.0
# 3         Tossed Salah     6.0
# 3                Nanas    12.0
# 3      Expected Ghouls     1.0
# 3       Cry me a River     7.0
# 3           Borocelona     3.0
# 3     Diego Marastebbo     4.0
# 3      Blaise Maweedie     2.0
# 3          Football FC    10.0
# 3   Debbie Does Gallas     5.0
# 3          Nanas Squad     9.0
# 3     Mike Dean's Bean    11.0
# 3  Tubbalubba Kings XI    13.0

# %%
# df_all[df_all.event==2].sort_values('total_points',ascending=False).total_points.iloc[8]

# %%
dist_list = []
for e in df_all.event.unique():
    dist_list+=(df_all[df_all.event==e].total_points - df_all[df_all.event==e].total_points.max()).tolist()

# %%
df_all['distpw_from_first'] = dist_list

# %%
dist_list9 = []
for e in df_all.event.unique():
    dist_list9+=(df_all[df_all.event==e].total_points - df_all[df_all.event==e].sort_values('total_points',ascending=False).total_points.iloc[8]).tolist()
df_all['distpw_from_ninth'] = dist_list9

# %%
dist_list9
# Out:
# [19.0,
#  1.0,
#  1.0,
#  13.0,
#  4.0,
#  8.0,
#  -3.0,
#  0.0,
#  3.0,
#  -4.0,
#  13.0,
#  -8.0,
#  -8.0,
#  13.0,
#  -1.0,
#  -3.0,
#  6.0,
#  -16.0,
#  -21.0,
#  0.0,
#  16.0,
#  37.0,
#  12.0,
#  28.0,
#  15.0,
#  16.0,
#  8.0,
#  37.0,
#  -30.0,
#  1.0,
#  30.0,
#  -6.0,
#  -1.0,
#  11.0,
#  13.0,
#  0.0,
#  8.0,
#  -39.0,
#  9.0,
#  3.0,
#  15.0,
#  -16.0,
#  48.0,
#  9.0,
#  25.0,
#  23.0,
#  42.0,
#  -6.0,
#  21.0,
#  0.0,
#  -9.0,
#  -26.0]

# %%
# create rank plot
gw = int(df_all.event.max())
curr_rank_list = df_all[df_all.event==gw].sort_values("total_points",ascending=False)["player"].tolist()
sns.set_style('dark')
plt.figure(figsize=(12,8))
ranking=sns.lineplot(y=df_all.rankpw,x=df_all.event,hue=df_all.player)
for i, name in enumerate(curr_rank_list):
    ranking.annotate(name,(gw+0.1,i+1))
plt.yticks(range(1,14))
plt.xticks(range(1,gw+1))
plt.xlim(0.5,gw+3)
plt.ylim(13.5,0.5)
plt.title("Ranking per Week")
plt.xlabel("Gameweek")
plt.ylabel("Rank")
plt.legend("")
plt.show()

# %%
# create dist plot
gw = int(df_all.event.max())
curr_dist = df_all[df_all.event==gw].sort_values("total_points",ascending=False)[["player","distpw_from_first"]]
sns.set_style('dark')
plt.figure(figsize=(14,10))
dist_first=sns.lineplot(y=df_all.distpw_from_first,x=df_all.event,hue=df_all.player)

# for row in curr_dist.index:
#     print(row)
#     ranking.annotate(name,(gw+0.1,i+1))

plt.xticks(range(1,gw+1))
plt.xlim(0.5,gw+3)

plt.title("Ranking per Week (by distance)")
plt.xlabel("Gameweek")
plt.ylabel("Distance from first")
plt.legend("")
plt.show()

# %%
df_all
# Out:
#    event  points  total_points       rank  rank_sort  overall_rank  bank  \
# 0    1.0   112.0         112.0    31939.0    36188.0       31939.0   0.0
# 0    1.0    94.0          94.0   817703.0   866188.0      817700.0   0.0
# 0    1.0    94.0          94.0   817703.0   863722.0      817700.0   0.0
# 0    1.0   106.0         106.0   122432.0   142017.0      122431.0   0.0
# 0    1.0    97.0          97.0   567570.0   589393.0      567567.0   0.0
# 0    1.0   101.0         101.0   316057.0   342750.0      316055.0   0.0
# 0    1.0    90.0          90.0  1176051.0  1259450.0     1176048.0   0.0
# 0    1.0    93.0          93.0   911355.0   942618.0      911352.0   0.0
# 0    1.0    96.0          96.0   633476.0   650790.0      633473.0   0.0
# 0    1.0    89.0          89.0  1281019.0  1308171.0     1281016.0   0.0
# 0    1.0   106.0         106.0   122432.0   124495.0      122431.0   5.0
# 0    1.0    85.0          85.0  1676991.0  1776464.0     1676988.0   5.0
# 0    1.0    85.0          85.0  1676991.0  1702477.0     1676988.0   0.0
# 1    2.0    76.0         172.0   639116.0   646858.0      359456.0   0.0
# 1    2.0    73.0         158.0   989758.0   998802.0      905892.0   5.0
# 1    2.0    59.0         156.0  2989925.0  3006366.0      973395.0   0.0
# 1    2.0    59.0         165.0  3086955.0  3120427.0      622171.0  20.0
# 1    2.0    54.0         143.0  4061611.0  4073943.0     1709129.0   0.0
# 1    2.0    53.0         138.0  4157158.0  4230337.0     2019692.0   5.0
# 1    2.0    69.0         159.0  1394131.0  1434721.0      841081.0   0.0
# 1    2.0    81.0         175.0   308476.0   320849.0      281909.0   0.0
# 1    2.0    84.0         196.0   180128.0   186184.0       22065.0   0.0
# 1    2.0    77.0         171.0   565755.0   580155.0      387441.0   0.0
# 1    2.0    81.0         187.0   308476.0   309898.0       69795.0   5.0
# 1    2.0    81.0         174.0   308476.0   317707.0      304407.0   0.0
# 1    2.0    74.0         175.0   823932.0   842416.0      281909.0   0.0
# 2    3.0    65.0         236.0  1608569.0  1632247.0      358601.0  13.0
# 2    3.0    69.0         265.0   905720.0   915975.0       16366.0   0.0
# 2    3.0    59.0         198.0  2944148.0  2956238.0     1900657.0   4.0
# 2    3.0    71.0         229.0   616314.0   626193.0      556051.0   1.0
# 2    3.0    71.0         258.0   652242.0   653225.0       38760.0   3.0
# 2    3.0    63.0         222.0  2029829.0  2070750.0      794432.0  11.0
# 2    3.0    71.0         227.0   652242.0   661543.0      620209.0   4.0
# 2    3.0    65.0         239.0  1550352.0  1568805.0      281624.0   4.0
# 2    3.0    69.0         241.0   905720.0   912269.0      247654.0   2.0
# 2    3.0    63.0         228.0  1966629.0  2003176.0      587740.0   9.0
# 2    3.0    61.0         236.0  2415508.0  2437086.0      351378.0   5.0
# 2    3.0    51.0         189.0  4807450.0  4843199.0     2425110.0   0.0
# 2    3.0    62.0         237.0  2253573.0  2279326.0      334038.0   9.0
# 3    4.0    60.0         288.0  3380799.0  3408086.0      635515.0   9.0
# 3    4.0    59.0         300.0  3622244.0  3628352.0      352336.0   2.0
# 3    4.0    71.0         269.0  1103054.0  1118774.0     1283644.0   3.0
# 3    4.0    76.0         333.0   568276.0   570601.0       21143.0   4.0
# 3    4.0    61.0         294.0  3187879.0  3205482.0      488576.0   6.0
# 3    4.0    71.0         310.0  1193031.0  1202393.0      188182.0   8.0
# 3    4.0    72.0         308.0  1044739.0  1053557.0      216372.0   0.0
# 3    4.0    73.0         327.0   906088.0   907178.0       39564.0   7.0
# 3    4.0    57.0         279.0  4104967.0  4143637.0      911026.0   9.0
# 3    4.0    74.0         306.0   775603.0   787391.0      251484.0  12.0
# 3    4.0    58.0         285.0  3864028.0  3876330.0      721597.0   3.0
# 3    4.0    47.0         276.0  6288344.0  6296432.0     1015027.0   6.0
# 3    4.0    74.0         259.0   775603.0   799094.0     1750575.0   9.0
#
#     value  event_transfers  event_transfers_cost  points_on_bench    player  \
# 0  1000.0              0.0                   0.0              2.0  Turnbull
# 0  1000.0              0.0                   0.0              1.0     James
# 0  1000.0              0.0                   0.0              3.0      Elks
# 0  1000.0              0.0                   0.0              5.0      Nick
# 0  1000.0              0.0                   0.0              2.0      Luke
# 0  1000.0              0.0                   0.0             12.0      Pete
# 0  1000.0              0.0                   0.0              6.0       Leo
# 0  1000.0              0.0                   0.0              4.0    George
# 0  1000.0              0.0                   0.0             14.0       Sam
# 0  1000.0              0.0                   0.0              8.0      Alex
# 0  1000.0              0.0                   0.0              9.0       Ted
# 0  1000.0              0.0                   0.0              8.0      Toby
# 0  1000.0              0.0                   0.0              4.0       Faz
# 1  1004.0              0.0                   0.0              8.0       Sam
# 1  1001.0              1.0                   0.0              4.0       Faz
# 1  1003.0              0.0                   0.0              0.0      Luke
# 1  1005.0              1.0                   0.0             11.0      Nick
# 1  1004.0              1.0                   0.0              3.0      Alex
# 1  1003.0              0.0                   0.0              2.0      Toby
# 1  1003.0              0.0                   0.0              1.0       Leo
# 1  1004.0              0.0                   0.0              0.0     James
# 1  1005.0              0.0                   0.0              2.0  Turnbull
# 1  1004.0              0.0                   0.0              8.0      Elks
# 1  1005.0              0.0                   0.0              4.0       Ted
# 1  1004.0              0.0                   0.0              4.0    George
# 1  1004.0              0.0                   0.0              0.0      Pete
# 2  1007.0              2.0                   0.0              1.0      Elks
# 2  1011.0              2.0                   0.0              1.0  Turnbull
# 2  1006.0              2.0                   4.0              6.0      Alex
# 2  1003.0              1.0                   0.0              3.0       Faz
# 2  1014.0              2.0                   0.0              4.0       Ted
# 2  1005.0              2.0                   0.0              1.0       Leo
# 2  1004.0              2.0                   0.0              2.0      Luke
# 2  1006.0              1.0                   0.0              2.0    George
# 2  1012.0              2.0                   0.0              4.0       Sam
# 2  1008.0              1.0                   0.0              4.0      Nick
# 2  1010.0              1.0                   0.0              3.0      Pete
# 2  1003.0              2.0                   0.0             12.0      Toby
# 2  1010.0              2.0                   0.0              1.0     James
# 3  1006.0              1.0                   0.0              3.0      Nick
# 3  1010.0              1.0                   0.0              0.0       Sam
# 3  1004.0              0.0                   0.0              5.0      Alex
# 3  1011.0              3.0                   8.0              7.0  Turnbull
# 3  1008.0              2.0                   4.0              8.0     James
# 3  1005.0              2.0                   0.0              6.0    George
# 3  1010.0              2.0                   0.0              1.0      Pete
# 3  1014.0              2.0                   4.0              0.0       Ted
# 3  1003.0              1.0                   0.0              0.0       Leo
# 3  1006.0              2.0                   4.0              8.0      Elks
# 3  1002.0              1.0                   0.0              9.0      Luke
# 3  1002.0              1.0                   0.0              7.0       Faz
# 3  1001.0              2.0                   4.0             10.0      Toby
#
#              team_name  rankpw  distpw_from_first  distpw_from_ninth
# 0      Expected Ghouls     1.0                0.0               19.0
# 0       Cry me a River     7.0              -18.0                1.0
# 0   Debbie Does Gallas     7.0              -18.0                1.0
# 0      Sissling Select     2.0               -6.0               13.0
# 0          Nanas Squad     5.0              -15.0                4.0
# 0     Diego Marastebbo     4.0              -11.0                8.0
# 0          Football FC    10.0              -22.0               -3.0
# 0           Borocelona     9.0              -19.0                0.0
# 0         Tossed Salah     6.0              -16.0                3.0
# 0                Nanas    11.0              -23.0               -4.0
# 0      Blaise Maweedie     2.0               -6.0               13.0
# 0  Tubbalubba Kings XI    12.0              -27.0               -8.0
# 0     Mike Dean's Bean    12.0              -27.0               -8.0
# 1         Tossed Salah     6.0              -24.0               13.0
# 1     Mike Dean's Bean    10.0              -38.0               -1.0
# 1          Nanas Squad    11.0              -40.0               -3.0
# 1      Sissling Select     8.0              -31.0                6.0
# 1                Nanas    12.0              -53.0              -16.0
# 1  Tubbalubba Kings XI    13.0              -58.0              -21.0
# 1          Football FC     9.0              -37.0                0.0
# 1       Cry me a River     3.0              -21.0               16.0
# 1      Expected Ghouls     1.0                0.0               37.0
# 1   Debbie Does Gallas     7.0              -25.0               12.0
# 1      Blaise Maweedie     2.0               -9.0               28.0
# 1           Borocelona     5.0              -22.0               15.0
# 1     Diego Marastebbo     3.0              -21.0               16.0
# 2   Debbie Does Gallas     6.0              -29.0                8.0
# 2      Expected Ghouls     1.0                0.0               37.0
# 2                Nanas    12.0              -67.0              -30.0
# 2     Mike Dean's Bean     8.0              -36.0                1.0
# 2      Blaise Maweedie     2.0               -7.0               30.0
# 2          Football FC    11.0              -43.0               -6.0
# 2          Nanas Squad    10.0              -38.0               -1.0
# 2           Borocelona     4.0              -26.0               11.0
# 2         Tossed Salah     3.0              -24.0               13.0
# 2      Sissling Select     9.0              -37.0                0.0
# 2     Diego Marastebbo     6.0              -29.0                8.0
# 2  Tubbalubba Kings XI    13.0              -76.0              -39.0
# 2       Cry me a River     5.0              -28.0                9.0
# 3      Sissling Select     8.0              -45.0                3.0
# 3         Tossed Salah     6.0              -33.0               15.0
# 3                Nanas    12.0              -64.0              -16.0
# 3      Expected Ghouls     1.0                0.0               48.0
# 3       Cry me a River     7.0              -39.0                9.0
# 3           Borocelona     3.0              -23.0               25.0
# 3     Diego Marastebbo     4.0              -25.0               23.0
# 3      Blaise Maweedie     2.0               -6.0               42.0
# 3          Football FC    10.0              -54.0               -6.0
# 3   Debbie Does Gallas     5.0              -27.0               21.0
# 3          Nanas Squad     9.0              -48.0                0.0
# 3     Mike Dean's Bean    11.0              -57.0               -9.0
# 3  Tubbalubba Kings XI    13.0              -74.0              -26.0

# %%
# create dist plot
gw = int(df_all.event.max())
curr_dist = df_all[df_all.event==gw].sort_values("total_points",ascending=False)[["player","distpw_from_ninth"]]
sns.set_style('dark')
plt.figure(figsize=(12,8))
dist_9th=sns.lineplot(y=df_all.distpw_from_ninth,x=df_all.event,hue=df_all.player,palette="colorblind")

last = 1000
for i in range(len(curr_dist)):
#     if last - curr_dist.iloc[i,1] < 5:
#         dist_9th.annotate(curr_dist.iloc[i,0],(gw+0.1,curr_dist.iloc[i,1]-5))
#     else:
    dist_9th.annotate(curr_dist.iloc[i,0],(gw+0.1,curr_dist.iloc[i,1]))
#     last = curr_dist.iloc[i,1]

plt.xticks(range(1,gw+1))
plt.xlim(0.5,gw+3)

plt.title("Distance from 9th")
plt.xlabel("Gameweek")
plt.ylabel("Distance from Ninth")
plt.legend("")
plt.grid(axis = "y")
plt.show()

# %%
# Current team value
df_temp = df_all[df_all['event']==df_all['event'].max()][['value','bank','player']].sort_values('value')
# df_temp['']
plt.figure(figsize=(12,8))
team_value = sns.barplot(y=df_temp['value']/10,x=df_temp.player,palette='PuBuGn_d')
plt.title("Current Team Value")
plt.xticks(rotation=30,ha="right")
for p in team_value.patches:
    team_value.annotate(round(p.get_height(),2), (p.get_x() + p.get_width() / 2., p.get_height()),
     ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
     textcoords='offset points')
plt.ylim(96,108)
plt.show()

# %% [markdown]
# ## Looking at ownership

# %%
#Formatting names
df_league['player'] = df_league['player_name'].apply(lambda x: "Alex Andreou" if x == "A A" else x)
df_league['player'] = df_league['player'].apply(lambda x: "Turnbull" if x == "Henry Turnbull" else x)
df_league['player'] = df_league['player'].apply(lambda x: "Elks" if x == "Henry Elks" else x)
df_league['player'] = df_league['player'].apply(lambda x: x.split()[0])

# %%
#Looping through and creating a df of the leagues picks
for row in df_league.index:
    url = "https://fantasy.premierleague.com/api/entry/{}/event/{}/picks/".format(df_league.iloc[row,7],gw)
    r = requests.get(url)
    picks = r.json()
    if row == 0:
        df_picks = pd.DataFrame(picks['picks'])
        df_picks['player'] = df_league.iloc[row,-1]
    else:
        df_temp = pd.DataFrame(picks['picks'])
        df_temp['player'] = df_league.iloc[row,-1]
        df_picks = pd.concat([df_picks,df_temp])

# %%
url = 'https://fantasy.premierleague.com/api/bootstrap-static/'
r = requests.get(url)
json_data = r.json()
player_df = pd.DataFrame(json_data['elements'])
teams_df = pd.DataFrame(json_data['teams'])
player_df.team = player_df.team.map(pd.Series(teams_df.name.values,teams_df.id).to_dict())

# %%
df_picks['web_name'] = df_picks.element.map(pd.Series(player_df.web_name.values,player_df.id).to_dict())
df_picks['team']=df_picks.element.map(pd.Series(player_df.team.values,player_df.id).to_dict())

# %%
df_picks.head()
# Out:
#    element  position  multiplier  is_captain  is_vice_captain    player  \
# 0       69         1           1       False            False  Turnbull
# 1      237         2           1       False            False  Turnbull
# 2      275         3           1       False            False  Turnbull
# 3       67         4           1       False            False  Turnbull
# 4      418         5           1       False            False  Turnbull
#
#            web_name       team
# 0           Sánchez   Brighton
# 1  Alexander-Arnold  Liverpool
# 2              Shaw    Man Utd
# 3             White    Arsenal
# 4            Coufal   West Ham

# %%
df_EO = df_picks.groupby(["web_name","team"])[['multiplier']].sum()/len(df_league.index)*100
df_EO = df_EO.reset_index()
df_EO = df_EO[df_EO.multiplier>1/len(df_league.index)*100]
df_EO = df_EO.sort_values(by='multiplier',ascending=False)

# %%
plt.figure(figsize=(6,10))
EO_plot = sns.barplot(y=df_EO.web_name,x=df_EO.multiplier,hue=df_EO.team,dodge=False,palette='Paired')
plt.title("Effective Ownership GW-{}".format(gw))
plt.xlabel("EO %")
plt.ylabel("")
for p in EO_plot.patches:
    EO_plot.annotate(round(p.get_width(),2), (p.get_width(),p.get_y()+p.get_height()/1.5),
     ha='left', va='center', fontsize=10, color='black', xytext=(0, 5),
     textcoords='offset points')
plt.show()

# %%
df_picks[df_picks.web_name == "Salah"]
# Out:
#    element  position  multiplier  is_captain  is_vice_captain    player  \
# 5      233         6           1       False             True  Turnbull
# 7      233         8           1       False             True       Ted
# 4      233         5           1       False             True    George
# 4      233         5           1       False             True      Pete
# 6      233         7           1       False             True      Elks
# 4      233         5           1       False             True       Sam
# 4      233         5           1       False            False     James
# 7      233         8           1       False             True      Nick
# 6      233         7           2        True            False      Luke
# 5      233         6           1       False            False       Leo
# 5      233         6           1       False            False      Alex
# 6      233         7           1       False            False      Toby
#
#   web_name       team
# 5    Salah  Liverpool
# 7    Salah  Liverpool
# 4    Salah  Liverpool
# 4    Salah  Liverpool
# 6    Salah  Liverpool
# 4    Salah  Liverpool
# 4    Salah  Liverpool
# 7    Salah  Liverpool
# 6    Salah  Liverpool
# 5    Salah  Liverpool
# 5    Salah  Liverpool
# 6    Salah  Liverpool

# %%
# Cheeky differentials
df_diff = df_picks.groupby(["web_name"])[['multiplier']].sum()
df_diff = df_diff[df_diff.multiplier==1]
df_diff = df_diff.reset_index()
df_diff['player'] = df_diff.web_name.map(pd.Series(df_picks[df_picks.multiplier!=0].player.values,df_picks[df_picks.multiplier!=0].web_name).to_dict())
df_diff.drop('multiplier',inplace=True,axis=1)
df_diff.columns = ["Rogue Choice", "Manager"]
df_diff = df_diff.sort_values('Manager')
df_diff = df_diff.set_index('Manager')

# %%
df_diff
# Out:
#          Rogue Choice
# Manager
# Alex            Allan
# Alex         Tanganga
# James            Zaha
# James        Reguilón
# James     Lucas Moura
# James         Jiménez
# James            Wood
# James        Gündogan
# James       Fabianski
# Leo            Ayling
# Luke            Duffy
# Luke      Wan-Bissaka
# Luke          Bamford
# Luke           Soucek
# Nick          Ederson
# Nick      Richarlison
# Pete          Sissoko
# Toby      A.Armstrong
# Toby             Dier
# Toby         Harrison
# Turnbull       Coufal

# %%
player_df
# Out:
#      chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 0                             NaN                           NaN   80201
# 1                             0.0                           0.0  115918
# 2                             0.0                           0.0   47431
# 3                           100.0                         100.0   54694
# 4                             NaN                           NaN   58822
# ..                            ...                           ...     ...
# 594                           0.0                           0.0  209353
# 595                           NaN                           NaN  245923
# 596                           NaN                           NaN  461026
# 597                           0.0                           0.0  481626
# 598                           NaN                           NaN  184754
#
#      cost_change_event  cost_change_event_fall  cost_change_start  \
# 0                    0                       0                 -1
# 1                    0                       0                  0
# 2                    0                       0                 -2
# 3                    0                       0                 -1
# 4                    0                       0                 -1
# ..                 ...                     ...                ...
# 594                  0                       0                  0
# 595                  0                       0                  0
# 596                  0                       0                  0
# 597                  0                       0                  0
# 598                  0                       0                  0
#
#      cost_change_start_fall  dreamteam_count  element_type ep_next  ...  \
# 0                         1                0             1     2.0  ...
# 1                         0                0             1     0.0  ...
# 2                         2                0             3     0.0  ...
# 3                         1                0             4     4.7  ...
# 4                         1                0             2     1.3  ...
# ..                      ...              ...           ...     ...  ...
# 594                       0                0             4     0.0  ...
# 595                       0                0             3     0.5  ...
# 596                       0                0             3     0.5  ...
# 597                       0                0             2     0.0  ...
# 598                       0                0             4     2.1  ...
#
#     threat_rank  threat_rank_type ict_index_rank ict_index_rank_type  \
# 0           488                50            207                  15
# 1           315                14            390                  35
# 2           589               241            592                 241
# 3            30                11             78                  18
# 4           293                98            225                  72
# ..          ...               ...            ...                 ...
# 594         533                64            554                  70
# 595         457               179            500                 192
# 596         467               185            509                 197
# 597         342               124            415                 151
# 598         124                31            211                  32
#
#      corners_and_indirect_freekicks_order  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 594                                   NaN
# 595                                   NaN
# 596                                   NaN
# 597                                   NaN
# 598                                   NaN
#
#      corners_and_indirect_freekicks_text direct_freekicks_order  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           5.0
# ..                                   ...                    ...
# 594                                                         NaN
# 595                                                         NaN
# 596                                                         NaN
# 597                                                         NaN
# 598                                                         NaN
#
#     direct_freekicks_text  penalties_order penalties_text
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      1.0
# 4                                      NaN
# ..                    ...              ...            ...
# 594                                    NaN
# 595                                    NaN
# 596                                    NaN
# 597                                    NaN
# 598                                    NaN
#
# [599 rows x 67 columns]

# %%
# Captaining error

#LoopThrough league managers

    #Loop through gws
#         #Loop through active players
url = "https://fantasy.premierleague.com/api/entry/1409005/event/4/picks/"
r = requests.get(url)
picks = r.json()
df_temp3 = pd.DataFrame(picks['picks']) 
df_temp3


# for player in df_temp3.element:
# load player history - link to fixtures to find gw and then look back up in player history
#compare all multiplier 1 to multiplier 2 - if no multiplier 2 then max
# Out:
#     element  position  multiplier  is_captain  is_vice_captain
# 0       270         1           1       False            False
# 1       262         2           1       False            False
# 2       273         3           1       False            False
# 3       229         4           1       False            False
# 4       250         5           1       False            False
# 5       171         6           1       False            False
# 6       233         7           2        True            False
# 7       422         8           1       False            False
# 8       189         9           1       False            False
# 9       205        10           1       False             True
# 10      337        11           1       False            False
# 11      200        12           0       False            False
# 12      169        13           0       False            False
# 13      429        14           0       False            False
# 14      188        15           0       False            False

# %%
url = "https://fantasy.premierleague.com/api/element-summary/273/"
r = requests.get(url)
json_data = r.json()
pd.DataFrame(json_data['history'])
# Out:
#    element  fixture  opponent_team  total_points  was_home  \
# 0      273        6             10             2      True
# 1      273       19             16             1     False
# 2      273       30             20             7     False
# 3      273       38             14             2      True
#
#            kickoff_time  team_h_score  team_a_score  round  minutes  ...  bps  \
# 0  2021-08-14T11:30:00Z             5             1      1       90  ...   12
# 1  2021-08-22T13:00:00Z             1             1      2       90  ...    5
# 2  2021-08-29T15:30:00Z             0             1      3       90  ...   30
# 3  2021-09-11T14:00:00Z             4             1      4       90  ...   14
#
#    influence  creativity  threat  ict_index  value  transfers_balance  \
# 0       10.0         0.9     4.0        1.5     55                  0
# 1       12.6         1.2     7.0        2.1     55             -38065
# 2       27.2         0.7    22.0        5.0     55             -77057
# 3       26.8         2.6    17.0        4.6     55             -79121
#
#    selected  transfers_in  transfers_out
# 0    842854             0              0
# 1    925801         33832          71897
# 2    873199         20207          97264
# 3    817449         28529         107650
#
# [4 rows x 31 columns]

# %%
df_league
# Out:
#           id  event_total         player_name  rank  last_rank  rank_sort  \
# 0   20241183           76      Henry Turnbull     1          1          1
# 1   16819673           73          Ted Rosner     2          2          2
# 2   25158712           71  George Baker Baker     3          4          3
# 3   22488436           72       Pete Stebbing     4          6          4
# 4   21699595           74          Henry Elks     5          7          5
# 5   20076908           59           Sam Guest     6          3          6
# 6   16523966           61        James Rivers     7          5          7
# 7   23673927           60       Nick Sissling     8          9          8
# 8   23446904           58         Luke Betham     9         10          9
# 9   33365266           57         Leo Anthias    10         11         10
# 10  43941031           47   James Fazackerley    11          8         11
# 11  29875475           71                 A A    12         12         12
# 12  48853375           74         Toby Powell    13         13         13
#
#     total    entry           entry_name    player
# 0     333  1364762      Expected Ghouls  Turnbull
# 1     327   107878      Blaise Maweedie       Ted
# 2     310  1796385           Borocelona    George
# 3     308  1861744     Diego Marastebbo      Pete
# 4     306  2631883   Debbie Does Gallas      Elks
# 5     300   776505         Tossed Salah       Sam
# 6     294  2805214       Cry me a River     James
# 7     288  3651523      Sissling Select      Nick
# 8     285  1583735          Nanas Squad      Luke
# 9     279  4910848          Football FC       Leo
# 10    276  1447926     Mike Dean's Bean     James
# 11    269  1390493                Nanas      Alex
# 12    259  6229066  Tubbalubba Kings XI      Toby

# %%
## Publishing to datapane

# %%
dp.login(token="091830a120b8c1f1cde36fd23c9e06d4b81bfc6b")
r = dp.Report(
    f'### Effective Ownership FPL League',

    
    dp.Select(blocks=[
        dp.Plot(ranking,responsive=False, label='Ranking'),
        dp.Plot(dist_9th,responsive=False, label='Distance from Ninth place'),
        dp.Plot(EO_plot,responsive=False,label="Effective Ownership"),
        dp.Table(df_diff,label="Full Differentials")
    ]),
    dp.Select(blocks=[
        dp.Plot(bench_chart,responsive=False, label='Points on Bench'),
        dp.Plot(x_transfers,responsive=False, label='Hits'),
        dp.Plot(max_week,responsive=False, label='Biggest Week'),
        dp.Plot(consistency,responsive=False, label='Consistency'),
        dp.Plot(current_percentile,responsive=False, label='Current %'),
        dp.Plot(team_value,responsive=False, label='Team Value')],type=dp.SelectType.TABS)
    
)
# Out:
# Connected successfully to https://datapane.com as lukebetham

# %%
dp.login(token="091830a120b8c1f1cde36fd23c9e06d4b81bfc6b")
data = dp.Report(
    f'### Effective Ownership FPL League - data',
    dp.DataTable(df_all)
)
# Out:
# Connected successfully to https://datapane.com as lukebetham

# %%
r.upload(name=f'Effective Ownership', open=True, description=f'')
# Out:
# Uploading report and associated data - *please wait...*
# Report successfully uploaded, click [here](https://datapane.com/u/lukebetham/reports/O7vZ4p7/effective-ownership/) to view and share your report

# %%
data.publish(name=f'Effective Ownership Data', open=True, description=f'')
# Out:
# Publishing document and associated data - *please wait...*
# Report successfully published at https://datapane.com/u/lukebetham/reports/effective-ownership-data/ - you can edit and add additional text from the link

# %%
df_all[df_all.event==1].total_points.rank(method='min',ascending=False)

# %%
df_all[df_all['event']==14]
